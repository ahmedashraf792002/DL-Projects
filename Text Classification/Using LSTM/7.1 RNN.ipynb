# %%
import csv
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, LSTM, Dropout, Activation, Embedding,SimpleRNN,LSTM
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk import word_tokenize
STOPWORDS = set(stopwords.words('english'))
from string import punctuation
punct = list(punctuation)
from tqdm import tqdm
from keras.callbacks import ReduceLROnPlateau,EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Ahmed
# [nltk_data]     Ashraf\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
data=pd.read_csv('bbc-text.csv')
data.head()
# Out:
#         category                                               text
# 0           tech  tv future in the hands of viewers with home th...
# 1       business  worldcom boss  left books alone  former worldc...
# 2          sport  tigers wary of farrell  gamble  leicester say ...
# 3          sport  yeading face newcastle in fa cup premiership s...
# 4  entertainment  ocean s twelve raids box office ocean s twelve...

# %%
articles=data['text']
labels=data['category']

# %%
def tokenize(sentence):
    return word_tokenize(sentence)
def clean(sentence):
    words=[]
    for word in tokenize(sentence):
        if  word not in STOPWORDS and word not in punct and not word.isdigit():
            words.append(word.lower())
    return ' '.join(words)

# %%
for i in tqdm(range(len(articles))):
    articles[i]=clean(articles[i])
articles.head()
# Out:
# 100%|██████████| 2225/2225 [00:05<00:00, 431.74it/s]
# 0    tv future hands viewers home theatre systems p...
# 1    worldcom boss left books alone former worldcom...
# 2    tigers wary farrell gamble leicester say rushe...
# 3    yeading face newcastle fa cup premiership side...
# 4    ocean twelve raids box office ocean twelve cri...
# Name: text, dtype: object

# %%
vocab_size =5000
embedding_dim =64
max_length =200
oov_tok = '<OOV>' #  Out of Vocabulary
training_portion = 0.8

# %%
len(labels),len(articles)
# Out:
# (2225, 2225)

# %%
labels[0],articles[0]
# Out:
# ('tech',
#  'tv future hands viewers home theatre systems plasma high-definition tvs digital video recorders moving living room way people watch tv radically different five years time according expert panel gathered annual consumer electronics show las vegas discuss new technologies impact one favourite pastimes us leading trend programmes content delivered viewers via home networks cable satellite telecoms companies broadband service providers front rooms portable devices one talked-about technologies ces digital personal video recorders dvr pvr set-top boxes like us tivo uk sky+ system allow people record store play pause forward wind tv programmes want essentially technology allows much personalised tv also built-in high-definition tv sets big business japan us slower take europe lack high-definition programming people forward wind adverts also forget abiding network channel schedules putting together a-la-carte entertainment us networks cable satellite companies worried means terms advertising revenues well brand identity viewer loyalty channels although us leads technology moment also concern raised europe particularly growing uptake services like sky+ happens today see nine months years time uk adam hume bbc broadcast futurologist told bbc news website likes bbc issues lost advertising revenue yet pressing issue moment commercial uk broadcasters brand loyalty important everyone talking content brands rather network brands said tim hanlon brand communications firm starcom mediavest reality broadband connections anybody producer content added challenge hard promote programme much choice means said stacey jolna senior vice president tv guide tv group way people find content want watch simplified tv viewers means networks us terms channels could take leaf google book search engine future instead scheduler help people find want watch kind channel model might work younger ipod generation used taking control gadgets play might suit everyone panel recognised older generations comfortable familiar schedules channel brands know getting perhaps want much choice put hands mr hanlon suggested end kids diapers pushing buttons already everything possible available said mr hanlon ultimately consumer tell market want new gadgets technologies showcased ces many enhancing tv-watching experience high-definition tv sets everywhere many new models lcd liquid crystal display tvs launched dvr capability built instead external boxes one example launched show humax 26-inch lcd tv 80-hour tivo dvr dvd recorder one us biggest satellite tv companies directtv even launched branded dvr show 100-hours recording capability instant replay search function set pause rewind tv hours microsoft chief bill gates announced pre-show keynote speech partnership tivo called tivotogo means people play recorded programmes windows pcs mobile devices reflect increasing trend freeing multimedia people watch want want')

# %%
train_size = int(len(articles) * training_portion)
train_articles = articles[0: train_size]
train_labels = labels[0: train_size]
validation_articles = articles[train_size:]
validation_labels = labels[train_size:]

# %%
print('train_articles' ,len(train_articles))
print('train_labels', len(train_labels))
print('validation_articles', len(validation_articles))
print('validation_labels', len(validation_labels))
# Out:
# train_articles 1780
# train_labels 1780
# validation_articles 445
# validation_labels 445

# %%
tokenizer = Tokenizer(num_words = vocab_size)
tokenizer.fit_on_texts(train_articles)
word_index = tokenizer.word_index

# %%
word_index
# Out:
# {'said': 1,
#  'mr': 2,
#  'would': 3,
#  'year': 4,
#  'also': 5,
#  'people': 6,
#  'new': 7,
#  'us': 8,
#  'one': 9,
#  'could': 10,
#  'last': 11,
#  'first': 12,
#  'time': 13,
#  'two': 14,
#  'government': 15,
#  'world': 16,
#  'uk': 17,
#  'best': 18,
#  'years': 19,
#  'make': 20,
#  'film': 21,
#  'told': 22,
#  'made': 23,
#  'get': 24,
#  'music': 25,
#  'game': 26,
#  'like': 27,
#  'back': 28,
#  'many': 29,
#  'labour': 30,
#  'three': 31,
#  'well': 32,
#  'next': 33,
#  'bbc': 34,
#  'take': 35,
#  'set': 36,
#  'number': 37,
#  'added': 38,
#  'way': 39,
#  'market': 40,
#  'company': 41,
#  'may': 42,
#  'says': 43,
#  'election': 44,
#  'home': 45,
#  'party': 46,
#  'good': 47,
#  'going': 48,
#  'much': 49,
#  'work': 50,
#  'still': 51,
#  'win': 52,
#  'show': 53,
#  'think': 54,
#  'games': 55,
#  'go': 56,
#  'top': 57,
#  'second': 58,
#  'million': 59,
#  'england': 60,
#  'firm': 61,
#  'since': 62,
#  'week': 63,
#  'say': 64,
#  'play': 65,
#  'part': 66,
#  '1': 67,
#  'public': 68,
#  'use': 69,
#  'blair': 70,
#  'want': 71,
#  'minister': 72,
#  'however': 73,
#  'country': 74,
#  'technology': 75,
#  'see': 76,
#  'five': 77,
#  'british': 78,
#  'news': 79,
#  'european': 80,
#  'high': 81,
#  'group': 82,
#  'tv': 83,
#  '6': 84,
#  'used': 85,
#  'end': 86,
#  'expected': 87,
#  'even': 88,
#  'players': 89,
#  'brown': 90,
#  'six': 91,
#  'old': 92,
#  'net': 93,
#  'already': 94,
#  'four': 95,
#  'plans': 96,
#  'put': 97,
#  'come': 98,
#  'half': 99,
#  'london': 100,
#  'sales': 101,
#  'growth': 102,
#  'long': 103,
#  'economy': 104,
#  'service': 105,
#  'right': 106,
#  'months': 107,
#  'chief': 108,
#  'day': 109,
#  'mobile': 110,
#  'former': 111,
#  'money': 112,
#  'britain': 113,
#  'director': 114,
#  'tax': 115,
#  '2': 116,
#  'services': 117,
#  'deal': 118,
#  'need': 119,
#  'help': 120,
#  'digital': 121,
#  'according': 122,
#  'big': 123,
#  'industry': 124,
#  'place': 125,
#  'companies': 126,
#  'users': 127,
#  'system': 128,
#  'business': 129,
#  'including': 130,
#  'team': 131,
#  'final': 132,
#  'based': 133,
#  'hit': 134,
#  'record': 135,
#  'report': 136,
#  'third': 137,
#  'called': 138,
#  'really': 139,
#  'international': 140,
#  'month': 141,
#  'move': 142,
#  'wales': 143,
#  'europe': 144,
#  'another': 145,
#  'life': 146,
#  '3': 147,
#  'around': 148,
#  'economic': 149,
#  'start': 150,
#  'great': 151,
#  'future': 152,
#  'firms': 153,
#  'got': 154,
#  'came': 155,
#  'france': 156,
#  'open': 157,
#  'spokesman': 158,
#  'software': 159,
#  'without': 160,
#  'general': 161,
#  'club': 162,
#  'took': 163,
#  'ireland': 164,
#  'video': 165,
#  'howard': 166,
#  'know': 167,
#  'united': 168,
#  'online': 169,
#  'bank': 170,
#  'phone': 171,
#  'china': 172,
#  'far': 173,
#  'state': 174,
#  'campaign': 175,
#  'side': 176,
#  'law': 177,
#  'radio': 178,
#  'better': 179,
#  'court': 180,
#  'making': 181,
#  '4': 182,
#  'decision': 183,
#  'executive': 184,
#  'real': 185,
#  'media': 186,
#  'offer': 187,
#  'give': 188,
#  'computer': 189,
#  'found': 190,
#  'action': 191,
#  'able': 192,
#  'president': 193,
#  '7': 194,
#  'information': 195,
#  'despite': 196,
#  'office': 197,
#  'star': 198,
#  'lot': 199,
#  '5': 200,
#  'national': 201,
#  'line': 202,
#  'countries': 203,
#  'likely': 204,
#  'using': 205,
#  'away': 206,
#  'player': 207,
#  'internet': 208,
#  'saying': 209,
#  'every': 210,
#  'given': 211,
#  'security': 212,
#  'become': 213,
#  'left': 214,
#  'awards': 215,
#  'figures': 216,
#  'anti': 217,
#  'nations': 218,
#  'run': 219,
#  'eu': 220,
#  'cost': 221,
#  'prime': 222,
#  'role': 223,
#  'seen': 224,
#  'playing': 225,
#  'biggest': 226,
#  'man': 227,
#  'january': 228,
#  'data': 229,
#  'bill': 230,
#  'whether': 231,
#  'played': 232,
#  'later': 233,
#  'foreign': 234,
#  'although': 235,
#  'cup': 236,
#  'up': 237,
#  'hard': 238,
#  'award': 239,
#  'rise': 240,
#  'broadband': 241,
#  'times': 242,
#  'match': 243,
#  'chancellor': 244,
#  'oil': 245,
#  'pay': 246,
#  'lost': 247,
#  'taking': 248,
#  'house': 249,
#  'due': 250,
#  'past': 251,
#  'interest': 252,
#  'early': 253,
#  'never': 254,
#  'lord': 255,
#  'leader': 256,
#  'support': 257,
#  'case': 258,
#  'prices': 259,
#  'look': 260,
#  'microsoft': 261,
#  'shares': 262,
#  'michael': 263,
#  'legal': 264,
#  'analysts': 265,
#  'control': 266,
#  'believe': 267,
#  'december': 268,
#  'less': 269,
#  'days': 270,
#  'cut': 271,
#  'recent': 272,
#  'season': 273,
#  'little': 274,
#  'children': 275,
#  'e': 276,
#  'ahead': 277,
#  'earlier': 278,
#  'increase': 279,
#  'thought': 280,
#  'free': 281,
#  'john': 282,
#  'face': 283,
#  'research': 284,
#  'scotland': 285,
#  'important': 286,
#  'something': 287,
#  'current': 288,
#  'strong': 289,
#  'went': 290,
#  'issue': 291,
#  'secretary': 292,
#  'south': 293,
#  'local': 294,
#  'tory': 295,
#  'rights': 296,
#  'working': 297,
#  'power': 298,
#  'budget': 299,
#  'financial': 300,
#  'spending': 301,
#  'quarter': 302,
#  'access': 303,
#  'currently': 304,
#  'held': 305,
#  'major': 306,
#  'chance': 307,
#  'change': 308,
#  'trade': 309,
#  'films': 310,
#  'find': 311,
#  'looking': 312,
#  'try': 313,
#  'following': 314,
#  'sunday': 315,
#  'full': 316,
#  'tories': 317,
#  '0': 318,
#  'yet': 319,
#  'return': 320,
#  'series': 321,
#  'latest': 322,
#  'meeting': 323,
#  'share': 324,
#  'different': 325,
#  'website': 326,
#  'david': 327,
#  'winning': 328,
#  'almost': 329,
#  'injury': 330,
#  'sale': 331,
#  'must': 332,
#  'lead': 333,
#  'enough': 334,
#  'personal': 335,
#  'programme': 336,
#  'might': 337,
#  'police': 338,
#  'low': 339,
#  'band': 340,
#  'problems': 341,
#  'ever': 342,
#  'keep': 343,
#  'rate': 344,
#  'announced': 345,
#  'always': 346,
#  'key': 347,
#  'coach': 348,
#  'williams': 349,
#  'sold': 350,
#  'across': 351,
#  'performance': 352,
#  'dollar': 353,
#  'among': 354,
#  'behind': 355,
#  'ago': 356,
#  'list': 357,
#  'clear': 358,
#  'getting': 359,
#  'political': 360,
#  'victory': 361,
#  'mark': 362,
#  'chairman': 363,
#  'include': 364,
#  'women': 365,
#  'demand': 366,
#  'statement': 367,
#  'ms': 368,
#  'march': 369,
#  'february': 370,
#  'things': 371,
#  'term': 372,
#  'rather': 373,
#  'jobs': 374,
#  'minutes': 375,
#  'tuesday': 376,
#  'american': 377,
#  'chelsea': 378,
#  'claims': 379,
#  'done': 380,
#  'content': 381,
#  'continue': 382,
#  'point': 383,
#  'job': 384,
#  'manager': 385,
#  'means': 386,
#  'head': 387,
#  'problem': 388,
#  'title': 389,
#  'actor': 390,
#  'coming': 391,
#  'huge': 392,
#  'price': 393,
#  'asked': 394,
#  'released': 395,
#  'taken': 396,
#  'mail': 397,
#  'men': 398,
#  'union': 399,
#  'members': 400,
#  'india': 401,
#  'allow': 402,
#  'weeks': 403,
#  'wednesday': 404,
#  'act': 405,
#  'japan': 406,
#  'rugby': 407,
#  'plan': 408,
#  'tony': 409,
#  'global': 410,
#  'investment': 411,
#  'least': 412,
#  'result': 413,
#  'apple': 414,
#  'young': 415,
#  'network': 416,
#  'today': 417,
#  'within': 418,
#  'costs': 419,
#  'fans': 420,
#  'forward': 421,
#  'bid': 422,
#  'main': 423,
#  'french': 424,
#  'possible': 425,
#  'production': 426,
#  'needed': 427,
#  'running': 428,
#  'site': 429,
#  'beat': 430,
#  'november': 431,
#  'small': 432,
#  'war': 433,
#  'council': 434,
#  'consumer': 435,
#  'available': 436,
#  'saturday': 437,
#  'form': 438,
#  'warned': 439,
#  'thing': 440,
#  'monday': 441,
#  'cash': 442,
#  'vote': 443,
#  'hold': 444,
#  'several': 445,
#  'known': 446,
#  'wanted': 447,
#  'mps': 448,
#  'song': 449,
#  'pc': 450,
#  'issues': 451,
#  'total': 452,
#  'committee': 453,
#  'friday': 454,
#  'level': 455,
#  'live': 456,
#  'football': 457,
#  'though': 458,
#  'evidence': 459,
#  'policy': 460,
#  'prize': 461,
#  'version': 462,
#  'success': 463,
#  'led': 464,
#  'league': 465,
#  'search': 466,
#  'trying': 467,
#  'human': 468,
#  'calls': 469,
#  'previous': 470,
#  'buy': 471,
#  'sir': 472,
#  'recently': 473,
#  'saw': 474,
#  'web': 475,
#  'sony': 476,
#  'rates': 477,
#  'family': 478,
#  'parties': 479,
#  'aid': 480,
#  'single': 481,
#  'album': 482,
#  'centre': 483,
#  'eight': 484,
#  'name': 485,
#  'customers': 486,
#  'rules': 487,
#  'meet': 488,
#  'close': 489,
#  'development': 490,
#  'ministers': 491,
#  'others': 492,
#  'thursday': 493,
#  'health': 494,
#  'book': 495,
#  'competition': 496,
#  'stock': 497,
#  'agreed': 498,
#  'call': 499,
#  'phones': 500,
#  'difficult': 501,
#  'short': 502,
#  'let': 503,
#  'race': 504,
#  'yukos': 505,
#  'consumers': 506,
#  'popular': 507,
#  'comes': 508,
#  'co': 509,
#  'fact': 510,
#  'charles': 511,
#  'event': 512,
#  'hope': 513,
#  'failed': 514,
#  'fourth': 515,
#  'higher': 516,
#  'showed': 517,
#  'networks': 518,
#  'debt': 519,
#  'board': 520,
#  'actress': 521,
#  'commission': 522,
#  'trial': 523,
#  'city': 524,
#  'wants': 525,
#  'october': 526,
#  'italy': 527,
#  'choice': 528,
#  'york': 529,
#  'lib': 530,
#  'reported': 531,
#  'feel': 532,
#  'nothing': 533,
#  'conference': 534,
#  'project': 535,
#  'career': 536,
#  'bt': 537,
#  'sites': 538,
#  'boss': 539,
#  'points': 540,
#  'liberal': 541,
#  'late': 542,
#  'sure': 543,
#  '8': 544,
#  'liverpool': 545,
#  'festival': 546,
#  'reports': 547,
#  'black': 548,
#  'received': 549,
#  'annual': 550,
#  'together': 551,
#  'instead': 552,
#  'claim': 553,
#  'shows': 554,
#  'gaming': 555,
#  'tour': 556,
#  '9': 557,
#  'dvd': 558,
#  'break': 559,
#  'launch': 560,
#  'claimed': 561,
#  'paid': 562,
#  'mean': 563,
#  'devices': 564,
#  'christmas': 565,
#  'jones': 566,
#  'movie': 567,
#  'boost': 568,
#  'goal': 569,
#  'virus': 570,
#  'growing': 571,
#  'stage': 572,
#  'release': 573,
#  'age': 574,
#  'largest': 575,
#  'september': 576,
#  'large': 577,
#  'leading': 578,
#  'summer': 579,
#  'champion': 580,
#  'involved': 581,
#  'position': 582,
#  'arsenal': 583,
#  'west': 584,
#  'denied': 585,
#  'changes': 586,
#  'russian': 587,
#  'believes': 588,
#  'manchester': 589,
#  'profits': 590,
#  'paul': 591,
#  'singer': 592,
#  'iraq': 593,
#  'needs': 594,
#  'fall': 595,
#  'television': 596,
#  'products': 597,
#  'idea': 598,
#  'stop': 599,
#  'gordon': 600,
#  'parliament': 601,
#  'australian': 602,
#  'pressure': 603,
#  'sport': 604,
#  'love': 605,
#  'germany': 606,
#  'africa': 607,
#  'started': 608,
#  'create': 609,
#  'order': 610,
#  'scottish': 611,
#  'talks': 612,
#  'giant': 613,
#  'potential': 614,
#  'german': 615,
#  '2004': 616,
#  'test': 617,
#  'pre': 618,
#  'weekend': 619,
#  'quite': 620,
#  'round': 621,
#  'opening': 622,
#  'whole': 623,
#  'squad': 624,
#  'martin': 625,
#  'association': 626,
#  'special': 627,
#  'senior': 628,
#  'launched': 629,
#  'box': 630,
#  'chart': 631,
#  'oscar': 632,
#  'seven': 633,
#  'street': 634,
#  'rose': 635,
#  'value': 636,
#  'conservative': 637,
#  'sent': 638,
#  'stars': 639,
#  'ball': 640,
#  'car': 641,
#  'v': 642,
#  'anything': 643,
#  'grand': 644,
#  'groups': 645,
#  'hours': 646,
#  'accused': 647,
#  'stand': 648,
#  'remain': 649,
#  'cards': 650,
#  'either': 651,
#  'hopes': 652,
#  'ensure': 653,
#  'olympic': 654,
#  'simply': 655,
#  'robinson': 656,
#  'fight': 657,
#  'similar': 658,
#  'press': 659,
#  'smith': 660,
#  'range': 661,
#  'irish': 662,
#  'drive': 663,
#  'exchange': 664,
#  'rock': 665,
#  '2003': 666,
#  'official': 667,
#  'results': 668,
#  'bit': 669,
#  'appeal': 670,
#  'turn': 671,
#  'dr': 672,
#  'provide': 673,
#  'ukip': 674,
#  'immigration': 675,
#  'period': 676,
#  'makes': 677,
#  'target': 678,
#  'helped': 679,
#  'investors': 680,
#  'standard': 681,
#  'wrong': 682,
#  'sell': 683,
#  'attack': 684,
#  'commons': 685,
#  'fell': 686,
#  'independent': 687,
#  'tsunami': 688,
#  'particularly': 689,
#  'meanwhile': 690,
#  'comedy': 691,
#  'proposals': 692,
#  'education': 693,
#  'average': 694,
#  'energy': 695,
#  'lords': 696,
#  'ban': 697,
#  'gave': 698,
#  'impact': 699,
#  'via': 700,
#  'moment': 701,
#  'compared': 702,
#  'school': 703,
#  'happy': 704,
#  'card': 705,
#  'forced': 706,
#  'charge': 707,
#  'attacks': 708,
#  'spam': 709,
#  'generation': 710,
#  'force': 711,
#  'brought': 712,
#  'amount': 713,
#  'private': 714,
#  'community': 715,
#  'sector': 716,
#  'per': 717,
#  'bring': 718,
#  'fraud': 719,
#  'became': 720,
#  'fund': 721,
#  'euros': 722,
#  'extra': 723,
#  'systems': 724,
#  'everyone': 725,
#  'speech': 726,
#  'admitted': 727,
#  'poll': 728,
#  'history': 729,
#  'message': 730,
#  'numbers': 731,
#  '2005': 732,
#  'included': 733,
#  'widely': 734,
#  'gadget': 735,
#  'entertainment': 736,
#  'windows': 737,
#  'debate': 738,
#  'speaking': 739,
#  'selling': 740,
#  'hand': 741,
#  'bad': 742,
#  'department': 743,
#  'laws': 744,
#  'workers': 745,
#  'date': 746,
#  'australia': 747,
#  'charges': 748,
#  'markets': 749,
#  'night': 750,
#  'audience': 751,
#  'named': 752,
#  'russia': 753,
#  'comments': 754,
#  'soon': 755,
#  'worked': 756,
#  'staff': 757,
#  'agency': 758,
#  'view': 759,
#  'turned': 760,
#  'kilroy': 761,
#  'mike': 762,
#  'front': 763,
#  'member': 764,
#  'shot': 765,
#  'bush': 766,
#  'revealed': 767,
#  'areas': 768,
#  'download': 769,
#  'takes': 770,
#  're': 771,
#  'speed': 772,
#  'screen': 773,
#  'increased': 774,
#  'opposition': 775,
#  'university': 776,
#  'battle': 777,
#  'civil': 778,
#  'kennedy': 779,
#  'spend': 780,
#  'air': 781,
#  'finance': 782,
#  'newspaper': 783,
#  'opportunity': 784,
#  'concerns': 785,
#  'shown': 786,
#  'survey': 787,
#  'area': 788,
#  'cross': 789,
#  'white': 790,
#  'gone': 791,
#  'voters': 792,
#  'course': 793,
#  'original': 794,
#  'millions': 795,
#  'bought': 796,
#  'offered': 797,
#  '£1': 798,
#  'poor': 799,
#  'alan': 800,
#  'followed': 801,
#  'east': 802,
#  'concerned': 803,
#  'leave': 804,
#  'often': 805,
#  'decided': 806,
#  'insisted': 807,
#  'authorities': 808,
#  'outside': 809,
#  'b': 810,
#  'favourite': 811,
#  'terms': 812,
#  'defence': 813,
#  'step': 814,
#  'whose': 815,
#  'june': 816,
#  'story': 817,
#  'reached': 818,
#  'analyst': 819,
#  'lives': 820,
#  'created': 821,
#  'designed': 822,
#  'mini': 823,
#  'process': 824,
#  'non': 825,
#  'risk': 826,
#  'america': 827,
#  'body': 828,
#  'quality': 829,
#  'easy': 830,
#  'spent': 831,
#  'cuts': 832,
#  'becoming': 833,
#  'remains': 834,
#  'unit': 835,
#  'majority': 836,
#  'raise': 837,
#  'pop': 838,
#  'attempt': 839,
#  'musical': 840,
#  'r': 841,
#  'drugs': 842,
#  'hollywood': 843,
#  'challenge': 844,
#  'experience': 845,
#  'example': 846,
#  'debut': 847,
#  'nominated': 848,
#  'states': 849,
#  'reach': 850,
#  'credit': 851,
#  'messages': 852,
#  'levels': 853,
#  'winner': 854,
#  'ray': 855,
#  'robert': 856,
#  'silk': 857,
#  'watch': 858,
#  'andy': 859,
#  'situation': 860,
#  'focus': 861,
#  'taxes': 862,
#  'euro': 863,
#  'songs': 864,
#  'organisation': 865,
#  'build': 866,
#  'everything': 867,
#  'believed': 868,
#  'april': 869,
#  'tough': 870,
#  'central': 871,
#  'anyone': 872,
#  'signed': 873,
#  'j': 874,
#  'pcs': 875,
#  'captain': 876,
#  'rival': 877,
#  'device': 878,
#  'indian': 879,
#  'confirmed': 880,
#  'james': 881,
#  'titles': 882,
#  'businesses': 883,
#  'post': 884,
#  'technologies': 885,
#  'critics': 886,
#  'matter': 887,
#  'previously': 888,
#  'trading': 889,
#  'rest': 890,
#  'met': 891,
#  'began': 892,
#  'longer': 893,
#  'officials': 894,
#  'response': 895,
#  'probably': 896,
#  'nine': 897,
#  'hour': 898,
#  'row': 899,
#  'minute': 900,
#  'light': 901,
#  'cases': 902,
#  'magazine': 903,
#  'building': 904,
#  'worth': 905,
#  'account': 906,
#  'voice': 907,
#  'programs': 908,
#  'ask': 909,
#  'looked': 910,
#  'mp': 911,
#  'davis': 912,
#  'aviator': 913,
#  'threat': 914,
#  'to': 915,
#  'trust': 916,
#  'confidence': 917,
#  'looks': 918,
#  'g': 919,
#  'chinese': 920,
#  'machine': 921,
#  'gold': 922,
#  'category': 923,
#  'computers': 924,
#  'premiership': 925,
#  'host': 926,
#  'measures': 927,
#  'fast': 928,
#  'person': 929,
#  'ruled': 930,
#  'towards': 931,
#  'artists': 932,
#  'double': 933,
#  'training': 934,
#  'missed': 935,
#  'felt': 936,
#  'care': 937,
#  'agreement': 938,
#  'allowed': 939,
#  '10': 940,
#  'madrid': 941,
#  'scheme': 942,
#  'zealand': 943,
#  'fear': 944,
#  'theatre': 945,
#  'portable': 946,
#  'newcastle': 947,
#  'north': 948,
#  'serious': 949,
#  'spain': 950,
#  'management': 951,
#  'banks': 952,
#  'program': 953,
#  'figure': 954,
#  'johnson': 955,
#  'positive': 956,
#  'affected': 957,
#  'champions': 958,
#  'file': 959,
#  'deutsche': 960,
#  'google': 961,
#  'kept': 962,
#  'rising': 963,
#  'rule': 964,
#  'argued': 965,
#  'along': 966,
#  'death': 967,
#  'ceremony': 968,
#  'code': 969,
#  'income': 970,
#  'near': 971,
#  'approach': 972,
#  'machines': 973,
#  'built': 974,
#  'domestic': 975,
#  'moved': 976,
#  'stay': 977,
#  'profit': 978,
#  'illegal': 979,
#  'sound': 980,
#  'de': 981,
#  'doubt': 982,
#  'confident': 983,
#  'question': 984,
#  'gadgets': 985,
#  'defeat': 986,
#  'dropped': 987,
#  'lower': 988,
#  'described': 989,
#  'society': 990,
#  'effort': 991,
#  'successful': 992,
#  'websites': 993,
#  'significant': 994,
#  'thousands': 995,
#  'wide': 996,
#  'written': 997,
#  'deficit': 998,
#  'social': 999,
#  'athens': 1000,
#  ...}

# %%
tokenizer.texts_to_sequences(['the cat sat on my table'])
# Out:
# [[2936, 1177, 2149]]

# %%
train_sequences = tokenizer.texts_to_sequences(train_articles)
len(train_sequences)
# Out:
# 1780

# %%
train_padded = pad_sequences(train_sequences, maxlen=max_length)

# %%
len(train_padded),len(train_padded[0])
# Out:
# (1780, 200)

# %%
validation_sequences = tokenizer.texts_to_sequences(validation_articles)
validation_padded = pad_sequences(validation_sequences, maxlen=max_length)

# %%
dict_={}
for i,x in tqdm(enumerate(set(labels))):
    dict_[x]=i
dict_
# Out:
# 5it [00:00, ?it/s]
# {'tech': 0, 'sport': 1, 'politics': 2, 'business': 3, 'entertainment': 4}

# %%
training_label_seq = np.array([dict_[train_labels[i]] for i in tqdm(range(len(train_labels)))])
validation_label_seq = np.array([dict_[np.array(validation_labels)[i]] for i in tqdm(range(len(validation_labels)))])
# Out:
# 100%|██████████| 1780/1780 [00:00<00:00, 254990.30it/s]
# 100%|██████████| 445/445 [00:00<00:00, 74370.06it/s]

# %%
train_labels[0], training_label_seq[0]
# Out:
# ('tech', 0)

# %%
pd.DataFrame(training_label_seq).value_counts()
# Out:
# 1    410
# 3    404
# 2    331
# 4    320
# 0    315
# dtype: int64

# %%
pd.DataFrame(validation_label_seq).value_counts()
# Out:
# 3    106
# 1    101
# 0     86
# 2     86
# 4     66
# dtype: int64

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
plt.title("Distribution Of Train",fontsize=20)
sns.histplot(training_label_seq,color='red')
plt.xlabel('Label',fontsize=20)
plt.ylabel("Count",fontsize=20)
plt.subplot(1,2,2)
plt.title("Distribution Of Test",fontsize=20)
sns.histplot(validation_label_seq,color='red')
plt.xlabel('Label',fontsize=20)
plt.ylabel("Count",fontsize=20)
# Out:
# Text(0, 0.5, 'Count')

# %%
model = Sequential()
model.add(Embedding(vocab_size,embedding_dim))
model.add(Dropout(0.5))
model.add(LSTM(units =32))
model.add(Dropout(0.5))
model.add(Dense(5,activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, None, 64)          320000
#
#  dropout (Dropout)           (None, None, 64)          0
#
#  lstm (LSTM)                 (None, 32)                12416
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense (Dense)               (None, 5)                 165
#
# =================================================================
# Total params: 332,581
# Trainable params: 332,581
# Non-trainable params: 0
# _________________________________________________________________

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3)
early_stop=EarlyStopping(monitor='val_loss',patience=10)
model.compile(loss='sparse_categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
history = model.fit(train_padded, training_label_seq, epochs=50,
                    validation_data=(validation_padded, validation_label_seq),
                    callbacks=[reduce_lr,early_stop])
# Out:
# Epoch 1/50
# 56/56 [==============================] - 6s 69ms/step - loss: 1.5424 - accuracy: 0.3191 - val_loss: 1.2332 - val_accuracy: 0.4517 - lr: 0.0010
# Epoch 2/50
# 56/56 [==============================] - 3s 62ms/step - loss: 1.1410 - accuracy: 0.4674 - val_loss: 1.0028 - val_accuracy: 0.4787 - lr: 0.0010
# Epoch 3/50
# 56/56 [==============================] - 3s 54ms/step - loss: 0.9099 - accuracy: 0.5955 - val_loss: 0.8974 - val_accuracy: 0.5933 - lr: 0.0010
# Epoch 4/50
# 56/56 [==============================] - 3s 52ms/step - loss: 0.8398 - accuracy: 0.6461 - val_loss: 0.7575 - val_accuracy: 0.7011 - lr: 0.0010
# Epoch 5/50
# 56/56 [==============================] - 3s 54ms/step - loss: 0.5860 - accuracy: 0.8157 - val_loss: 0.5153 - val_accuracy: 0.8921 - lr: 0.0010
# Epoch 6/50
# 56/56 [==============================] - 3s 54ms/step - loss: 0.4171 - accuracy: 0.8860 - val_loss: 0.4328 - val_accuracy: 0.8315 - lr: 0.0010
# Epoch 7/50
# 56/56 [==============================] - 3s 53ms/step - loss: 0.2717 - accuracy: 0.9517 - val_loss: 0.2213 - val_accuracy: 0.9528 - lr: 0.0010
# Epoch 8/50
# 56/56 [==============================] - 3s 55ms/step - loss: 0.1748 - accuracy: 0.9809 - val_loss: 0.1719 - val_accuracy: 0.9708 - lr: 0.0010
# Epoch 9/50
# 56/56 [==============================] - 3s 60ms/step - loss: 0.1236 - accuracy: 0.9910 - val_loss: 0.1607 - val_accuracy: 0.9640 - lr: 0.0010
# Epoch 10/50
# 56/56 [==============================] - 3s 55ms/step - loss: 0.1015 - accuracy: 0.9899 - val_loss: 0.1328 - val_accuracy: 0.9730 - lr: 0.0010
# Epoch 11/50
# 56/56 [==============================] - 3s 55ms/step - loss: 0.0882 - accuracy: 0.9910 - val_loss: 0.1079 - val_accuracy: 0.9775 - lr: 0.0010
# Epoch 12/50
# 56/56 [==============================] - 3s 54ms/step - loss: 0.0755 - accuracy: 0.9921 - val_loss: 0.1956 - val_accuracy: 0.9506 - lr: 0.0010
# Epoch 13/50
# 56/56 [==============================] - 3s 51ms/step - loss: 0.0943 - accuracy: 0.9904 - val_loss: 0.1836 - val_accuracy: 0.9596 - lr: 0.0010
# Epoch 14/50
# 56/56 [==============================] - 3s 55ms/step - loss: 0.0932 - accuracy: 0.9854 - val_loss: 0.1361 - val_accuracy: 0.9640 - lr: 0.0010
# Epoch 15/50
# 56/56 [==============================] - 3s 51ms/step - loss: 0.0433 - accuracy: 0.9994 - val_loss: 0.1303 - val_accuracy: 0.9663 - lr: 1.0000e-04
# Epoch 16/50
# 56/56 [==============================] - 3s 49ms/step - loss: 0.0406 - accuracy: 0.9994 - val_loss: 0.1279 - val_accuracy: 0.9663 - lr: 1.0000e-04
# Epoch 17/50
# 56/56 [==============================] - 3s 52ms/step - loss: 0.0376 - accuracy: 0.9994 - val_loss: 0.1251 - val_accuracy: 0.9640 - lr: 1.0000e-04
# Epoch 18/50
# 56/56 [==============================] - 3s 51ms/step - loss: 0.0394 - accuracy: 0.9983 - val_loss: 0.1250 - val_accuracy: 0.9640 - lr: 1.0000e-05
# Epoch 19/50
# 56/56 [==============================] - 3s 49ms/step - loss: 0.0386 - accuracy: 1.0000 - val_loss: 0.1255 - val_accuracy: 0.9640 - lr: 1.0000e-05
# Epoch 20/50
# 56/56 [==============================] - 3s 50ms/step - loss: 0.0387 - accuracy: 0.9989 - val_loss: 0.1251 - val_accuracy: 0.9640 - lr: 1.0000e-05
# Epoch 21/50
# 56/56 [==============================] - 3s 50ms/step - loss: 0.0433 - accuracy: 0.9989 - val_loss: 0.1250 - val_accuracy: 0.9640 - lr: 1.0000e-06

# %%
pd.DataFrame(history.history)
# Out:
#         loss  accuracy  val_loss  val_accuracy        lr
# 0   1.542375  0.319101  1.233239      0.451685  0.001000
# 1   1.140972  0.467416  1.002801      0.478652  0.001000
# 2   0.909913  0.595506  0.897445      0.593258  0.001000
# 3   0.839828  0.646067  0.757514      0.701124  0.001000
# 4   0.585994  0.815730  0.515316      0.892135  0.001000
# 5   0.417064  0.885955  0.432818      0.831461  0.001000
# 6   0.271721  0.951685  0.221301      0.952809  0.001000
# 7   0.174755  0.980899  0.171902      0.970787  0.001000
# 8   0.123559  0.991011  0.160658      0.964045  0.001000
# 9   0.101517  0.989888  0.132832      0.973034  0.001000
# 10  0.088156  0.991011  0.107887      0.977528  0.001000
# 11  0.075494  0.992135  0.195646      0.950562  0.001000
# 12  0.094321  0.990449  0.183626      0.959551  0.001000
# 13  0.093222  0.985393  0.136062      0.964045  0.001000
# 14  0.043320  0.999438  0.130310      0.966292  0.000100
# 15  0.040607  0.999438  0.127937      0.966292  0.000100
# 16  0.037593  0.999438  0.125127      0.964045  0.000100
# 17  0.039443  0.998315  0.124974      0.964045  0.000010
# 18  0.038552  1.000000  0.125504      0.964045  0.000010
# 19  0.038695  0.998876  0.125080      0.964045  0.000010
# 20  0.043332  0.998876  0.125040      0.964045  0.000001

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
y_pred=model.predict(validation_padded)
# Out:
# 14/14 [==============================] - 0s 12ms/step

# %%
pred=[np.argmax(i) for i in tqdm(y_pred)]
df=pd.DataFrame()
df['Prediction'],df['actual']=pred,validation_label_seq
df
# Out:
# 100%|██████████| 445/445 [00:00<00:00, 223127.95it/s]
#      Prediction  actual
# 0             4       4
# 1             0       0
# 2             2       2
# 3             1       1
# 4             1       1
# ..          ...     ...
# 440           3       3
# 441           2       2
# 442           4       4
# 443           2       2
# 444           1       1
#
# [445 rows x 2 columns]

# %%
CM = confusion_matrix(validation_label_seq,pred)
plt.figure(figsize=(8,8))
ax= plt.subplot()
sns.heatmap(CM, center = True, fmt='g',ax=ax,annot=True,cmap='Blues_r')
ax.set_xlabel('Predicted labels',fontsize=20)
ax.set_ylabel('True labels',fontsize=20) 
ax.set_title('Confusion Matrix',fontsize=20)
ax.xaxis.set_ticklabels(dict_.keys()) 
ax.yaxis.set_ticklabels(dict_.keys())
plt.show()
CM
# Out:
# array([[ 85,   0,   0,   0,   1],
#        [  0, 101,   0,   0,   0],
#        [  1,   1,  82,   2,   0],
#        [  1,   0,   3, 102,   0],
#        [  2,   1,   0,   4,  59]], dtype=int64)

# %%
ClassificationReport = classification_report(validation_label_seq,pred)
print('Classification Report is : ', ClassificationReport )
# Out:
# Classification Report is :                precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97        86
#            1       0.98      1.00      0.99       101
#            2       0.96      0.95      0.96        86
#            3       0.94      0.96      0.95       106
#            4       0.98      0.89      0.94        66
#
#     accuracy                           0.96       445
#    macro avg       0.97      0.96      0.96       445
# weighted avg       0.96      0.96      0.96       445

# %%
def get_code(N):
    for x,y in dict_.items():
        if y==N:
            return x

# %%
txt = ["blair prepares to name poll date tony blair is likely to name 5 may as election day when parliament returns from its easter break  the bbc s political editor has learned.  andrew marr says mr blair will ask the queen on 4 or 5 april to dissolve parliament at the end of that week. mr blair has so far resisted calls for him to name the day but all parties have stepped up campaigning recently. downing street would not be drawn on the claim  saying election timing was a matter for the prime minister.  a number 10 spokeswoman would only say:  he will announce an election when he wants to announce an election.  the move will signal a frantic week at westminster as the government is likely to try to get key legislation through parliament. the government needs its finance bill  covering the budget plans  to be passed before the commons closes for business at the end of the session on 7 april.  but it will also seek to push through its serious and organised crime bill and id cards bill. mr marr said on wednesday s today programme:  there s almost nobody at a senior level inside the government or in parliament itself who doesn t expect the election to be called on 4 or 5 april.  as soon as the commons is back after the short easter recess  tony blair whips up to the palace  asks the queen to dissolve parliament ... and we re going.  the labour government officially has until june 2006 to hold general election  but in recent years governments have favoured four-year terms."]
seq = tokenizer.texts_to_sequences(txt)
padded = pad_sequences(seq, maxlen=max_length)
pred = model.predict(padded)
print(pred)
print(np.argmax(pred))
print(get_code(np.argmax(pred)))
# Out:
# 1/1 [==============================] - 0s 29ms/step
# [[1.9241396e-03 6.9129781e-04 9.8427910e-01 1.2462892e-02 6.4256543e-04]]
# 2
# politics

# %%
txt = ["call to save manufacturing jobs the trades union congress (tuc) is calling on the government to stem job losses in manufacturing firms by reviewing the help it gives companies.  the tuc said in its submission before the budget that action is needed because of 105 000 jobs lost from the sector over the last year. it calls for better pensions  child care provision and decent wages. the 36-page submission also urges the government to examine support other european countries provide to industry. tuc general secretary brendan barber called for  a commitment to policies that will make a real difference to the lives of working people.    greater investment in childcare strategies and the people delivering that childcare will increases the options available to working parents   he said.  a commitment to our public services and manufacturing sector ensures that we can continue to compete on a global level and deliver the frontline services that this country needs.  he also called for  practical measures  to help pensioners  especially women who he said  are most likely to retire in poverty . the submission also calls for decent wages and training for people working in the manufacturing sector."]

seq = tokenizer.texts_to_sequences(txt)
padded = pad_sequences(seq, maxlen=max_length)
pred = model.predict(padded)
print(pred)
print(np.argmax(pred))
print(get_code(np.argmax(pred)))
# Out:
# 1/1 [==============================] - 0s 23ms/step
# [[1.2417971e-03 3.2028963e-04 6.6204583e-03 9.9134666e-01 4.7081817e-04]]
# 3
# business
